# %% [markdown]
#  # MTH5001:  Introduction to Computer Programming 2021/22
#
# ## Final Report Project: "Atmospheric Carbon Dioxide Levels"
#
# <div class="alert alert-block alert-danger">
#
# **IMPORTANT**:
# Start by filling in your Name and student ID below. **DO IT NOW**. Save this Jupyter Notebook with the name *MTH5001_surname_ID.ipynb*, where instead of *surname* and *ID* you write your surname and your student ID number.
# Use the available cells to introduce the code. You can add additional cells if needed. explain your code as much as possible with `# comments` </div>
#
# <div class="alert alert-block alert-warning">
#
# ### Name: Oguntade Adeniji
#
# ### ID:200213239
#
#
#
#
# <br />

# %% [markdown]
# ### Instructions:
#
# You must write your answers in this Jupyter Notebook, using either Markdown or Python code as appropriate.
#
# Your code must be **well documented**. As a rough guide, you should aim to include one line of comments for each line of code (but you may include more or fewer comments depending on the situation).
#
# The total number of marks available is 100. Attempt all parts of all questions.
#
# For this project, you are expected to write your code almost entirely 'from scratch', although you are allowed to use some specific packages like `numpy`, `matplotlib.pyplot`, etc.
#
# ### Submission deadline:
#
# You must submit your work via QMPlus, to the "Final Report Project" assignment in the "Final Report Project" section under the "Assessment" tab.
#
# The submission deadline is **11:55pm on Thursday 5 May, 2022**. Late submissions will be penalised according to the School's [guidelines](https://qmplus.qmul.ac.uk/mod/book/view.php?id=1723496&chapterid=135310).
#
# Your lecturers will respond to project-related emails until 5:00pm on Tuesday 3 May, 2022, only. You should aim to have your project finished by this time.
#
# ### Marking of projects:
#
# When writing up projects, good writing style is even more important than in written exams. According to the [advice](https://qmplus.qmul.ac.uk/mod/book/view.php?id=1723496&chapterid=135293) in the student handbook,
#
# > To get full marks in any assessed work (tests or exams) you must normally not only give the right answers but also explain your working clearly and give reasons for your answers by writing legible and grammatically correct English sentences. Mathematics is about logic and reasoned arguments and the only way to present a reasoned and logical argument is by writing about it clearly. Your writing may include numbers and other mathematical symbols, but they are not enough on their own. You should copy the writing style used in good mathematical textbooks, such as those recommended for your modules. **You can expect to lose marks for poor writing (incorrect grammar and spelling) as well as for poor mathematics (incorrect or unclear logic).**
#
# <div class="alert alert-block alert-danger">
#
# ### Plagiarism warning:
#
# Your work will be tested for plagiarism, which is an assessment offence, according to the [School's policy on Plagiarism](https://qmplus.qmul.ac.uk/mod/book/view.php?id=1723496&chapterid=135294). In particular, while only academic staff will make a judgement on whether plagiarism has occurred in a piece of work, we will use the plagiarism detection software "Turnitin" to help us assess how much of work matches other sources. You will have the opportunity to upload your work, see the Turnitin result, and edit your work once accordingly before finalising your submission.
#
#
# However, you must use your own words as far as possible (within reason, e.g. you would not be expected to change the wording of a well-known theorem), and you **must** [reference](https://qmplus.qmul.ac.uk/mod/book/view.php?id=1723496&chapterid=135300) any sources that you use. You cannot communicate with other students on any part of the project. You should also note that some of the questions are personalised in the sense that you will need to import and manipulate data that will be unique to you (i.e. no other student will have the same data).

# %% [markdown]
# ---
# ### The Keeling curve
# This project deals with the analysis of atmospheric carbon dioxide levels as measured by the Mauna Loa Observatory in Hawaii over the last 50 years. This data is known as the [Keeling curve]( https://en.wikipedia.org/wiki/Keeling_Curve).
#
# ![image.png](attachment:image.png)
#
# This project consists of **four parts**. In each of the parts you will need to code up some specific functions, run some code, and respond to some questions. Recall that all code needs to be properly documented with `# comments`, and the explanations in these comments will indeed be assessed and you will receive lots of marks for adequate documentation.
#
#
#
# * The **first part** is about loading and visualising historical $CO_2$ levels in the atmosphere.
#
# * The **second part** asks you to write code for polynomial fitting.
#
# * The **third part** compares global and local trend fitting.
#
# * The **fourth part** focusses on the seasonal variations.
#
# <br />
#
#
# ---

# %% [markdown]
# The following code box is used to load any necessary modules. **You may not import any other modules.**

# %%
#DO NOT CHANGE THE CONTENT OF THIS CODE BOX
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Part 1: Loading and cleaning data [20 marks total]
# *** ***
#
# <div class="alert alert-block alert-danger">
#
# Please remember to write plenty of `# comments` in the code cells. Mark scheme is depicted in each question. 50% of the marks will go to assess the actual code, and 50% of the marks will go to assess the `# comments`. Remember also to **reference** any sources you used. If you used any code or coding ideas you found elsewhere, you are encouraged to do that in the `# comments`.

# %% [markdown]
# ---
#
# **[1.1] [6 marks]** Load the data from the file "Mauna_Loa_CO2.csv" into a pandas dataframe named `Mauna_Loa_df` and display it. You should get a dataframe with 2494 rows and 9 columns with the first column looking as follows:
# ![image-3.png](attachment:image-3.png)
#
# If you encounter difficulties doing this it may help to inspect the content of the csv file in a text editor.
#
# ---

# %%
Mauna_Loa_df=pd.read_csv('Mauna_Loa_CO2.csv')
# Initially I was struggling with opening the file and tried multiple ways of importing the csv. file.
# I realised then that actually the reason an error was occuring was because of the content of the csv.
# I then opened the csv. file and deleted all the text concerning publication details etc.


#I much later realised that the question actually asks to take out the extra information using code as it says 'inspect' the csv.
#I tried to redownload the csv. and used the below code 
# Mauna_Loa_df=pd.read_csv('Mauna_Loa_CO2.csv', skiprows=47)
# I used ‘skiprows’ from this link
# https://thispointer.com/pandas-skip-rows-while-reading-csv-file-to-a-dataframe-using-read_csv-in-python/ 
# However somehow it corrupted the cells for later questions and majority of my code stopped working

# Because of this I copied this project file and once again deleted all the unnecessary text and continued. 
Mauna_Loa_df
# Out:
#       year  month  day    decimal  average  ndays  1 year ago  10 years ago  \
# 0     1974      5   19  1974.3795   333.37      5     -999.99       -999.99
# 1     1974      5   26  1974.3986   332.95      6     -999.99       -999.99
# 2     1974      6    2  1974.4178   332.35      5     -999.99       -999.99
# 3     1974      6    9  1974.4370   332.20      7     -999.99       -999.99
# 4     1974      6   16  1974.4562   332.37      7     -999.99       -999.99
# ...    ...    ...  ...        ...      ...    ...         ...           ...
# 2489  2022      1   30  2022.0808   419.19      7      416.89        393.28
# 2490  2022      2    6  2022.1000   418.38      6      417.04        393.99
# 2491  2022      2   13  2022.1192   419.76      7      416.59        394.02
# 2492  2022      2   20  2022.1384   419.62      7      416.30        394.30
# 2493  2022      2   27  2022.1575   419.20      7      417.68        394.54
#
#       increase since 1800
# 0                   50.40
# 1                   50.06
# 2                   49.60
# 3                   49.65
# 4                   50.06
# ...                   ...
# 2489               138.47
# 2490               137.55
# 2491               138.82
# 2492               138.57
# 2493               138.03
#
# [2494 rows x 9 columns]

# %% [markdown]
# ---
# **[1.2] [6 marks]** Using this dataframe, produce a plot of the carbon dioxide data contained therein versus time. The relevant columns in the csv file are "average" and "decimal", containing average carbon dioxide levels in ppm and the date in years, respectively.
#
# Clearly label the content, a plot simply showing the defaults "average" and "decimal" will be insufficient.
#
# If you encounter difficulties it may help to inspect the content of the csv file or the dataframe directly.
#
# ---

# %%
#Using plt.plot() I assigned 'decimal' data on the x axis and 'average' data on the y
plt.plot(Mauna_Loa_df['decimal'], Mauna_Loa_df['average'], color='red')
#I also added some necassary titles and labels as well as colouring the graph red to signal the extremity of the increase in CO2
plt.title('CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
#plt.show() allowed me to neaten the graph by removing 'Text(0.5, 0, 'Time (from May 1974 to Feb 2022)')'
plt.show()

# %%
##Initially I attempted to write a function that deleted all other column in the dataset apart from 'decimal' and 'average'
##However, I soon realised this was a mistake because it didn't end up plotting the two columns of data against each other
#Instead both sets were put aginst the dataframe index. Below is this code I used intially.

#def historicalCO2levels(df):
#    return df.drop(columns=['year','month','day','ndays','1 year ago','10 years ago','increase since 1800'])
#CO2leveldata=historicalCO2levels(Mauna_Loa_df)
#CO2leveldata
#CO2leveldata.plot(logy=True)

# %% [markdown]
# ---
# **[1.3] [8 marks]** In the above plot you will have noted irregularities, presumably due to missing data. Describe these and amend the dataframe accordingly. Replot.
#
#
# ---

# %%
#Initially I perfomred the below function to help me evaluate all the values which were causing irregularities
#The function would show me the smallest values of 'average'
#I chose the first 20 smallest values and identified 18 were outliers
Mauna_Loa_df['average'].sort_values(ascending=True).head(20)
# Out:
# 518    -999.99
# 1639   -999.99
# 515    -999.99
# 516    -999.99
# 413    -999.99
# 412    -999.99
# 409    -999.99
# 84     -999.99
# 517    -999.99
# 82     -999.99
# 110    -999.99
# 1782   -999.99
# 81     -999.99
# 72     -999.99
# 1780   -999.99
# 1781   -999.99
# 83     -999.99
# 481    -999.99
# 17      326.72
# 18      326.99
# Name: average, dtype: float64

# %%
#Knowing the outliers, I made a new dataset that had the outliers removed
#I attempted to do this in a neater manner but settled with listing the dataframe indexs of the outliers
New_Mauna=Mauna_Loa_df.drop([518,1639,515,516,413,412,409,84,517,82,110,1782,81,72,1780,1781,83,481])
#I then copied my code from the previous question and swapped Mauna_Loa_df for New_Mauna
plt.plot(New_Mauna['decimal'], New_Mauna['average'], color='red')
plt.title('CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %% [markdown]
# # Part 2: Polynomial fitting [30 marks total]
# *** ***
#
# <div class="alert alert-block alert-danger">
#
# Please remember to write plenty of `# comments` in the code cells. Mark scheme is depicted in each question. 50% of the marks will go to assess the actual code, and 50% of the marks will go to assess the `# comments`. Remember also to **reference** any sources you used. If you used any code or coding ideas you found elsewhere, you are encouraged to do that in the `# comments`.

# %% [markdown]
# In this section you will develop a polynomial fitting routine in order to estimate the overall trend in the carbon dioxide curve. For this, you might want to refer to Section 7.7 in the [Linear Algebra lecture notes]( https://qmplus.qmul.ac.uk/pluginfile.php/2820808/mod_resource/content/3/notes2019.pdf) which was covered in week 11 of last term, in particular Theorem 7.35.
#
# ## Background information
#
# In many applications, we might be given a set of data points
#
# $$(x_1,y_1), (x_2,y_2), \ldots, (x_n,y_n)$$
#
# in the $x,y$-plane, and required to determine whether there is a relationship between the $x$ variable and the $y$ variable.
# For example, a financial analyst might need to determine whether there is a relationship between two stock prices, while a climate scientist might need to know whether temperatures are related to levels of a certain pollutant in the atmosphere.
#
# A common way to determine whether two data sets $x_1, x_2, \ldots, x_n$ and $y_1, y_2, \ldots, y_n$ are related is to find a function
#
# $$y = f(x)$$
#
# that 'best fits' the data, so that each $y_i$ is approximately equal to $f(x_i)$, with very small error.
#
# In order to find the 'best fit' the data, one attempts to minimise the **sum of squares of the errors (or "SSE")**,
#
# $$SSE = \sum_{i=1}^n (y_i - f(x_i))^2$$
#
# In other words, we want to minimise the sums of the squares of all the differences between the actual $y$-values (the $y_i$) and the 'predicted' $y$-values by substituting the corresponding $x_i$ values into the equation $y = f(x)$.
#
# This process is called **least squares regression**.

# %% [markdown]
# The function $f(x)$ usually depends on certain parameters for which we need to solve.
# For example, to determine whether the $x$- and $y$-variables have a **linear relationship**, we would use a linear function
#
# $$f(x) = a_0 + a_1 x$$
#
# and try to find the parameters $a_0$ and $a_1$ that make $f(x)$ 'best fit' the data.
# This means that we want to find the coefficients $a_0$ and $a_1$ for which the quantity
# $$SSE = \sum_{i=1}^n (y_i - a_0 - a_1x_i)^2$$ is minimised.

# %% [markdown]
# More generally, **polynomial (least squares) regression** involves assuming that
#
# $$f(x) = a_0 + a_1 x + a_2 x^2 + \cdots + a_m x^m$$
#
# for some integer $m \geq 1$, and finding the parameters $a_0, a_1, a_2 \ldots, a_m$ that minimise SSE. In other words, we wish to fit a function
#
# $$f(x) = a_0 + a_1x + a_2x^2 + \cdots a_mx^m$$
#
# to our data points $(x_1,y_1), (x_2,y_2), \ldots, (x_n,y_n)$, where $m$ is some (chosen but arbitrarily large) positive integer.
# Observe that $m=1$ for linear regression, and $m=2$ for quadratic regression.
# We need to minimise
#
# $$SSE = ||y - f(x)||^2.$$
#
# for polynomial regression we therefore consider the matrices
#
# $$X = \left[ \begin{array}{ll} 1&x_0&x_0^2&\cdots&x_0^m \\ 1&x_1&x_1^2&\cdots&x_1^m \\ \vdots&\vdots \\ 1&x_n&x_n^2&\cdots&x_n^m \end{array} \right], \quad
# \mathbf{y} = \left[ \begin{array}{l} y_1 \\ y_2 \\ \vdots \\ y_n \end{array} \right], \quad \text{and} \quad
# \mathbf{a} = \left[ \begin{array}{l} a_0 \\ a_1 \\ a_2 \\ \vdots \\ a_m \end{array} \right],$$
#
# and we again find that
#
# $$SSE = ||\mathbf{y} - X\mathbf{a}||^2,$$
#
# meaning that $\mathbf{a}$ should be chosen to be a least squares solution of the system $X\mathbf{a} = \mathbf{y}$.
# Hence, we can find $\mathbf{a}$ by solving the normal equations
#
# $$(X^TX)\mathbf{a} = X^T\mathbf{y}.$$
#
# more details, in particular proofs, are given in Section 7.7 in the [Linear Algebra lecture notes]( https://qmplus.qmul.ac.uk/pluginfile.php/2820808/mod_resource/content/3/notes2019.pdf).

# %% [markdown]
# Python provides this functionality with the function polyfit. If you followed instructions precisely, the following should work for you.
#
# ```python
#
# np.polyfit(Mauna_Loa_df["decimal"],Mauna_Loa_df["average"],2)

# %% [markdown]
# ---
# **[2.1] [5 marks]** Ensure that the above line of code works for your dataframe.
#
# Note: you may have to consult the documentation about the meaning of the output.
#
# ---

# %%
np.polyfit?
#In order to determine what input corresponds to, I used '?' to inquire

# %%
#I then realised the actual corresponding coefficients would be from the New_Mauna table as that is the updated Mauna_Loa_df
#Hence, I then renamed the table as it's original name to avoid confusion in the furture
Mauna_Loa_df=New_Mauna
np.polyfit(Mauna_Loa_df["decimal"],Mauna_Loa_df["average"],2)
# Out:
# array([ 1.37021827e-02, -5.29516062e+01,  5.14639463e+04])

# %% [markdown]
# ---
# **[2.2] [10 marks]** This gives you coefficients for a quadratic fit. Plot the carbon dioxide data together with the fitted curve.
#
# ---

# %%
np.polyfit?
#In order to determine what input corresponds to, I used '?' to inquire
#After inquiring the function 'np.polyfit', it is said to return:
#"Polynomial coefficients, highest power first."
#From this, we can determine that the polynomial regression of the graph is y=1.37021827e-02x^2-5.29516062e+01x+5.14639463e+04

# %%
plt.plot?
#I then enquired plt,plot in order to remind myself of what inputs the function takes. I also took a look at the week 1 lab
#This reminded me of some features plt.plot had, for example linewidth which I encorperated to make the function more visible.

# %%
#Firstly I allocated x as the x-axis 'Mauna_Loa_df["decimal"]'
x=Mauna_Loa_df["decimal"]
#Then I used plt.plot and input the x, quadratic function(y), colour and linewidth respectively
plt.plot(x, (1.37021827e-02*x**2)+(-5.29516062e+01*x)+5.14639463e+04, color='black', linewidth=4)
#I then pasted my graph from question 1.3
plt.plot(Mauna_Loa_df["decimal"], Mauna_Loa_df["average"], color='red')
plt.title('CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %% [markdown]
# ---
# **[2.3] [10 marks]** We now would like you to replace the polyfit function by your own code, without making reference to any provided fitting routines: write a function `least_squares_solver_polynomial` which takes as input a pandas dataframe with two numerical columns containing x and y values, and the degree $m$ of a polynomial (a positive integer), and computes the corresponding polynomial regression coefficients $a_0, a_1, a_2, \ldots, a_m$. The output of your function should be a **list** of the form `[a0, a1, a2, ..., am]` containing the $m+1$ coefficients $a_0, a_1, a_2, \ldots, a_m$ in that order.
#
# Note: you are allowed to use np.linalg.solve(), but not np.polyfit() or similar.
#
# ---

# %%
np.linalg.solve?
#First I queried what this function does so I could get an idea of when to impliment it

# %%
#This function took a very long time to make to match all the necessary criteria
def least_squares_solver_polynomial(dataframe,m):
    '''This function returns a list contatining coeffieicents of a polynomial equation when you input a two column dataframe,
    as well as the dergee of polynomial, m'''
#This part of the function is needed in order to turn a pandas dataframe to a list/array that python can manipulate more easily
##'https://pythonguides.com/python-convert-dataframe-to-list/' is the link for the website where I found the code in the 2 
##lines below. 
    df=pd.DataFrame(dataframe)
    df=df.values.tolist()
#From this point onwards I followed the week 12 lab walkthrough where a part of the lab was almost identical to this question
#I calculated the number of rows in x
    n=len(dataframe)
#I then used a for loop to create the x matrix in (X^T X)a=X^T y
    x=[[1] for i in range(n)]
    for i in range(n):
        for j in range(1,m+1):
            x[i].append(df[i][0]**j)
#Then I created a y vector which was easier as it only has one dimension
    y=[[df[i][1]] for i in range(n)]
#'https://numpy.org/doc/stable/reference/generated/numpy.transpose.html' is what I used to get the transpose function 
    XT=np.transpose(x)
#I then used the provided np.linlag.solve to solve linear matrix equation. I used @ to multiply the 2 matrices in (X^TX)a=X^Ty
#This function produced my values but as an array so I used list() to make output a list and make it look neater 
    return list(np.linalg.solve(XT@x, XT@y).tolist())

# %% [markdown]
# ---
# **[2.4] [5 marks]** Run your least squares solver by using
# ```python
# least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],2)
# ```
#
# and compare the output with the above result obtained by using polyfit. How good is the agreement?
#
# ---

# %%
#the function worked! 
least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],2)
# Out:
# [[51464.02340599546], [-52.951683305769414], [0.013702202002174679]]

# %% [markdown]
# # Part 3: Global fitting versus local fitting [25 marks total]
# *** ***
#
# <div class="alert alert-block alert-danger">
#
# Please remember to write plenty of `# comments` in the code cells. Mark scheme is depicted in each question. 50% of the marks will go to assess the actual code, and 50% of the marks will go to assess the `# comments`. Remember also to **reference** any sources you used. If you used any code or coding ideas you found elsewhere, you are encouraged to do that in the `# comments`.

# %% [markdown]
# If you look carefully you will notice that a quadratic fit is perhaps not the best way to capture the trend. There are two ways to improve this
#
# 1. You can experiment with taking higher degree polynomials
# 2. You can do local fits by computing averages
#
# Note: if you did not manage to get least_squares_solver_polynomial to work, you are permitted to use polyfit instead.

# %% [markdown]
# ---
# **[3.1] [10 marks]** A good way to eyeball the quality of the fit and to check for systematic errors is to plot the difference between the actual and the fitted data. Produce plots showing this difference for fits with degrees one (linear) to six and describe what you can conclude.
#
# ---

# %%
#I started by finding what the coefficients would be of the linear fit for the 'CO2 levels over time graph' 
least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],1)
# Out:
# [[-3250.150157734828], [1.811087772084777]]

# %%
#Now that I found these coefficeints, I copied the code used in question(2.2) and removed the alteration in colour and linewidth
#I then edited the function used in the 'y' input according to the new coefficients and degrees of polynomial
#I then bracketed this so it was one function and I then pasted in 'Mauna_Loa_df["average"]' and took the function away from it
#Now, the output is a graph showing the difference in the actual data(pandas column) and the fitted data(function)
x=Mauna_Loa_df["decimal"]
plt.plot(x,Mauna_Loa_df["average"]-((1.811087772084777*x)+-3250.150157734828))
plt.title('difference between fitted and actual CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %%
#I repeated the process again
least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],2)
# Out:
# [[51464.02340599546], [-52.951683305769414], [0.013702202002174679]]

# %%
#However, this time around I was able to not edit the function in the plot and copy and paste question(2.4) exactly
x=Mauna_Loa_df["decimal"]
plt.plot(x,(Mauna_Loa_df["average"])-((0.013702202002174679*x**2)+(-52.951683305769414*x)+51464.02340599546))
plt.title('difference between fitted and actual CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %%
#Repeated the process again but changed m=3
a=least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],3)
print(a)
#I then realised that a quicker more efficient way of typing in coefficients would be to allocate 'a' name for the list
#that least_squares_solver_polynomial() produces and then put appropriate values in list as coefficients using 'a[0]','a[1]'etc
# Out:
# [[-2236879.155859271], [3382.691134921212], [-1.7056355167261101], [0.0002868010314201118]]

# %%
x=Mauna_Loa_df["decimal"]
plt.plot(x,Mauna_Loa_df["average"]-((a[3]*x**3)+(a[2]*x**2)+(a[1]*x)+a[0]))
plt.title('difference between fitted and actual CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %%
#I then started to notice that as I repeated the process with higher degrees, the graphs started to look increasingly similar 
b=least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],4)
print(b)
# Out:
# [[-1726366.7352801315], [2415.999625210884], [-1.0214558032646361], [7.238259971505533e-05], [2.509370045058327e-08]]

# %%
x=Mauna_Loa_df["decimal"]
plt.plot(x,Mauna_Loa_df["average"]-((b[4]*x**4)+(b[3]*x**3)+(b[2]*x**2)+(b[1]*x)+b[0]))
plt.title('difference between fitted and actual CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %%
c=least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],5)
print(c)
# Out:
# [[-579431.6125334563], [436.72367970319874], [0.08745710607490617], [-5.579335418047039e-05], [-4.719466157228091e-08], [1.7437080082467957e-11]]

# %%
x=Mauna_Loa_df["decimal"]
plt.plot(x,Mauna_Loa_df["average"]-((c[5]*x**5)+(c[4]*x**4)+(c[3]*x**3)+(c[2]*x**2)+(c[1]*x)+c[0]))
plt.title('difference between fitted and actual CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %%
#This was my last iteration of the process
d=least_squares_solver_polynomial(Mauna_Loa_df[["decimal","average"]],6)
print(d)
# Out:
# [[-560800.5504130399], [347.8166286025221], [0.18617424256360876], [-7.75186641878028e-05], [-6.901352671867574e-08], [3.04814890629596e-11], [-2.034410488205149e-15]]

# %%
x=Mauna_Loa_df["decimal"]
plt.plot(x,Mauna_Loa_df["average"]-((d[6]*x**6)+(d[5]*x**5)+(d[4]*x**4)+(d[3]*x**3)+(d[2]*x**2)+(d[1]*x)+d[0]))
plt.title('difference between fitted and actual CO2 levels over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %% [markdown]
# ---
# **[3.2] [8 marks]** Now produce local fits. A very simple approach is to compute an average across a full year, with the date you want to estimate right in the middle. (Note: depending on how you code this, you may have to make reasonable adjustments towards the start and the end of your time range.)
#
# To do this, you should first write a function
# ```python
# def local_fit(data,xmin,xmax):
#     # add your code
#     return yaverage
# ```
# that takes a  takes as input a pandas dataframe with two numerical columns containing x and y values, and two values xmin and xmax and returns the average over all values of y for which xmin < x < xmax.
#
# As an example,
# ```python
# local_fit(Mauna_Loa_df[["decimal","average"]],2000,2001)
# ```
# should give a carbon dioxide concentration of around 369.7 ppm.
#
# ---

# %%
#when starting to write this function my inital instinct was to use boolean type code as we are attempting to work in a range
#Initially I tried using a for loop but I found this too complicated and was resulting in multiple errors
#I then wrote this function
def local_fit(data,xmin,xmax):
#I allocated the first column and the second column with 'col1' and 'col2'
#I did this because questions asks for two numerical columns containing x and y values
#https://stackoverflow.com/questions/39158699/how-to-select-column-and-rows-in-pandas-without-column-or-row-names
#This web address was where I found the code to isolate a column of a pandas dataframe
    col1=data.iloc[:,0]
    col2=data.iloc[:,1]
#I then used .loc to isolate the rows that follow the boolean conditions of larger than xmin but smaller than xmax 
    col_range=data.loc[(col1>=xmin)&(col1<xmax)]
#I then found the average of y by isolating it in col_range (say'col2range'). Then I divided sum of col2range by its length        
    yaverage=sum(col_range.iloc[:,1])/len(col_range.iloc[:,1])
#I then outputed the result and it was around 369.7 ppm
    return yaverage

# %%
# Then when testing the result was accurate
local_fit(Mauna_Loa_df[["decimal","average"]],2000,2001)
# Out:
# 369.73301886792456

# %% [markdown]
# ---
# **[3.3] [7 marks]** Now that you have the local averaging, produce two plots, one displaying the average per year and
# one displaying the difference to that average.
#
# ---

# %%
list_avg=[local_fit(Mauna_Loa_df[["decimal","average"]],1974+i,1975+i) for i in range(2022-1974)]
#I then tried to run this with Mauna_Loa_df["decimal"] being x, however it wouldnt work as the two lists had different lengths
#So, I created a list called dates in range 1974 and 2022 to assure x and y had the same dimensions 
dates=[1974+j for j in range(2022-1974)]
#I then plotted these lists
plt.plot(dates,list_avg)
#I then called the graph 'Average CO2 levels per year over time'
plt.title('Average CO2 levels per year over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %%
# Then, to plot a graph displaying the difference to the average per year, I changed the range paramters of list_avg   
list_avg=[local_fit(Mauna_Loa_df[["decimal","average"]],i,i+1) for i in Mauna_Loa_df["decimal"]] 
# I then plotted the difference between the average and the average per year by taking list_avg away from 'average' dataset
plt.plot(Mauna_Loa_df["decimal"],Mauna_Loa_df["average"]-list_avg)
plt.title('The difference of the average CO2 levels, per year, over time')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (from May 1974 to Feb 2022)')
plt.show()

# %% [markdown]
# # Part 4: Looking at the yearly variations [25 marks total]
# *** ***
#
# <div class="alert alert-block alert-danger">
#
# Please remember to write plenty of `# comments` in the code cells. Mark scheme is depicted in each question. 50% of the marks will go to assess the actual code, and 50% of the marks will go to assess the `# comments`. Remember also to **reference** any sources you used. If you used any code or coding ideas you found elsewhere, you are encouraged to do that in the `# comments`.

# %% [markdown]
# For this part, we consider the difference between the carbon dioxide levels and the yearly averages. This data, while noisy, seems to oscillate with a period of one year, and it makes therefore sense to look at this oscillation more closely. In an nutshell, we are going to work towards obtaining a picture similar to the one in the inset in the Keeling curve figure at the top of this document.

# %% [markdown]
# ---
# **[4.1] [10 marks]** Plot the differences obtained in Question 3.3 versus the time of year as measured in months.
#
# Note: it is advisable to plot individual data points that are not connected by lines
#
# ---

# %%
# I first copy and pasted the list_avg to clarify my coding to myself 
list_avg=[local_fit(Mauna_Loa_df[["decimal","average"]],i,i+1) for i in Mauna_Loa_df["decimal"]]
#The note advised to use individual points so I used plt.scatter not plt.plot, which I found in the link below
#https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.scatter.html
#I alsp used the site to look at the optional inputs of plt.scatter and neatened my graph
#I then repeated the same x value for x but changed the y value to Mauna_Loa_df["months"] in order to measure in months
plt.scatter(Mauna_Loa_df["month"],Mauna_Loa_df["average"]-list_avg, marker='*', s=5)
plt.title('Average CO2 levels in a year (in months)')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (January-December)')
#As well as labels and titles, I also found a function on the internet, plt.xticks that helped me label the months
#https://stackoverflow.com/questions/50201466/change-the-x-axis-from-numbers-to-months
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
year=np.linspace(1,12,12)
plt.xticks(year, months)
plt.show()
#The graph illustrates all the y values in that given month which is why it looks different to other previous graphs

# %% [markdown]
# ---
# **[4.2] [10 marks]** Find a sensible way of interpolating the data you just plotted. Add the curve thus obtained to the plot in the previous question. You may notice that there is some roughness in your plot that indicates that we are at the limit of what we can sensibly analyse.
#
# Note: this question is stated purposefully vaguely to give you a chance to showcase your talent (or your prowess with Google). As a timely reminder, any use of code found online must be carefully referenced, otherwise it will be deemed plagiarism.
#
# ---

# %%
#Biulding from the previous question, I again copy and pasted list_avg and then created a new column on the Mauna_Loa_df
list_avg=[local_fit(Mauna_Loa_df[["decimal","average"]],i,i+1) for i in Mauna_Loa_df["decimal"]]
#I called this new dataset 'interpolation' and its values are the difference in the average CO2 levels 
Mauna_Loa_df['interpolation']=Mauna_Loa_df['average']-list_avg
#I then sorted the values of month in numerical order so that my graph did not go back and forth on x axis
Mauna_Loa_df.sort_values('month')
#I then plotted the local fit of 'month' and new 'interpolation' using a range of 12 so I could match dimensiosn of linspace x
#12 was chosen as it is the highest value of month due to it being the number of months in a year
plt.plot( np.linspace(1,12,12),[local_fit(Mauna_Loa_df[["month","interpolation"]],i,i+1) for i in range(1,13)])
#I then repeated labelling process
plt.title('Average CO2 levels in a year (in months)')
plt.ylabel('Volume of Carbon Dioxide (in parts per million)')
plt.xlabel('Time (January to December)')
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
year=np.linspace(1,12,12)
plt.xticks(year, months)
plt.show()

# %% [markdown]
# ---
# **[4.3] [5 marks]** You are now in a position to clearly separate overall trend, seasonal variation, and residual effects. Finish the project by creating a plot of the residual noise, similar to the bottom graph in the image below. Describe how the residual effects compare to the seasonal variation.
#
# (You are welcome to provide all four plots together, but you will only be assessed on plotting the residual effects.)
#
#
# ![image.png](attachment:image.png)
#
# ---

# %%
#Finally, to find the residual plot I plotted the y in the previous question take away the 'interpelation' dataset to get the remaining 'average' data
#I had to put plt.figure to the front of the line of code in order for my plot to look as such. I found the code for it here
#https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.figure.html
#I messed around with the dimensions until I got something that ressembled the exampled graph
plt.figure(figsize=(40,4))
#I labelled the graph to have likeness to the example graphs given
plt.xlabel('Date')
plt.ylabel('Residual')
plt.plot(Mauna_Loa_df['decimal'],[local_fit(Mauna_Loa_df[["month","interpolation"]],i,i+1) for i in Mauna_Loa_df['month']]-Mauna_Loa_df['interpolation'])
plt.show()
#I finished the project and enjoyed doing it!
